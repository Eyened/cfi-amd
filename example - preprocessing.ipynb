# %%
from PIL import Image
import numpy as np

from cfi_amd.utils.mask_extraction import get_cfi_bounds
image = np.array(Image.open('sample/image0.png'))
bounds = get_cfi_bounds(image)
bounds
# Out:
# #### CFIBounds:
#
#         - Center: (974.5464299152146, 965.0029663857364)
#         - Radius: 936.0624313601943
#         - Top: 28
#         - Bottom: 1902
#         - Left: 38
#         - Right: 1911

# %%
from matplotlib import pyplot as plt
fig, axes = plt.subplots(1, 4, figsize=(10, 5))
for ax in axes:
    ax.axis('off')
axes[0].imshow(image)
axes[1].imshow(bounds.contrast_enhanced_2)
axes[2].imshow(bounds.contrast_enhanced_5)
axes[3].imshow(bounds.contrast_enhanced_10)
